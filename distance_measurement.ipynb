# %%
from prody import parsePDB, buildDistMatrix
import glob
import pandas as pd
import re

# %%
models = glob.glob('models/*.pdb')
models
# Out:
# ['models/LMQCWQLLA_66.pdb',
#  'models/LVLFDLDED_45718.pdb',
#  'models/VLISPVSIL_45835.pdb',
#  'models/KLFSYGTLI_5.pdb',
#  'models/GLNLEGSGV_45778.pdb',
#  'models/DKIDQIIHD_45749.pdb',
#  'models/TPQFLLQLN_45658.pdb',
#  'models/QQGIVRQRV_45809.pdb',
#  'models/GLLIVKTVL_45750.pdb',
#  'models/GLKISLCGI_24.pdb',
#  'models/MLIGIEILN_45901.pdb',
#  'models/VLFRLENHA_12.pdb',
#  'models/LTPKAQREI_1.pdb',
#  'models/KFPYEGGKV_45658.pdb',
#  'models/SLSNLDFRL_1414,8.pdb',
#  'models/AQRWANQIR_114.pdb',
#  'models/YLEPGPVTA_240.pdb',
#  'models/QLREAATEA_1.pdb',
#  'models/WMDMWESPM_6.pdb',
#  'models/GLHCYEQLV_198.pdb',
#  'models/GVSTDIPSA_45839.pdb',
#  'models/TVLDHILQK_45901.pdb',
#  'models/SLSSQMTST_1.pdb',
#  'models/TFALKKLII_45839.pdb',
#  'models/AENTNTSKS_45809.pdb',
#  'models/YITDYSNDI_12.pdb',
#  'models/SQYDPKELL_12.pdb',
#  'models/HLTRVGPYL_174.pdb',
#  'models/QLIIQAFEA_45749.pdb',
#  'models/SVMLIGIEI_45748.pdb',
#  'models/YLAEGHACL_804.pdb',
#  'models/RTSFFLWVI_45809.pdb',
#  'models/QSLGAEIAV_54.pdb',
#  'models/FIVEHINAM_42.pdb',
#  'models/VLRDDLCEA_47348.pdb',
#  'models/VLSELPDFL_18.pdb',
#  'models/ILDTGTIQL_468.pdb',
#  'models/QRVIPVYQV_45809.pdb',
#  'models/GQFLSFASL_1.pdb',
#  'models/QLSNTTGRL_45691.pdb',
#  'models/AMEDLVRAY_306.pdb',
#  'models/IMYNYPTML_240.pdb',
#  'models/QLSAIALGV_45778.pdb',
#  'models/FQLNDTIHL_45902.pdb',
#  'models/VLYCVHQEI_162.pdb',
#  'models/KLGIGNSPV_188.pdb',
#  'models/YLVDYGLVS_45810.pdb',
#  'models/VKYLEGHGF_45809.pdb',
#  'models/AIGLAWIPY_45748.pdb',
#  'models/GTGVGKTSQ_45778.pdb',
#  'models/LRFANPLSN_45809.pdb',
#  'models/FSYGTLIID_45901.pdb',
#  'models/MLGHAGDMA_84.pdb',
#  'models/CLPPPPDGV_45872.pdb',
#  'models/YQVKYVSPV_1392.pdb',
#  'models/LIWTLDANI_45839.pdb',
#  'models/DSMFLMTAT_45810.pdb',
#  'models/STFIMLEGE_45748.pdb',
#  'models/RPVILSLPR_45748.pdb',
#  'models/LRTFSILNR_45810.pdb',
#  'models/KNSPGMVPL_1.pdb',
#  'models/LLFGYPVYV_453.pdb',
#  'models/NVGEQYQQL_1.pdb',
#  'models/VLSGYIASV_1716.pdb',
#  'models/VGLITCKAF_45778.pdb',
#  'models/YLHIHPFKI_264.pdb',
#  'models/YLFGGFSTL_45812.pdb',
#  'models/QGIVRQRVI_45749.pdb',
#  'models/NGTLEFTPI_45748.pdb',
#  'models/HMMKDEPVV_45905.pdb',
#  'models/GSYGEYQSY_45717.pdb',
#  'models/FLSFASLFL_45781.pdb',
#  'models/EDLIEWAME_45725.pdb',
#  'models/IMYNYPAML_324.pdb',
#  'models/ASTVIYRGT_45839.pdb',
#  'models/LEKVQRQIQ_45748.pdb',
#  'models/FYTRVLKPS_45809.pdb',
#  'models/RYVHKVSGT_45778.pdb',
#  'models/YLMAWKQVL_1530.pdb',
#  'models/AWQSVGHMM_45809.pdb',
#  'models/KVQRQIQVH_45811.pdb',
#  'models/RMWEFLDRL_48.pdb',
#  'models/RTRREAIVN_45748.pdb',
#  'models/NLNVTTQSI_1.pdb',
#  'models/GMVPLHIPE_45778.pdb',
#  'models/FMVAWGKEA_48.pdb',
#  'models/ILGLPTQTV_474.pdb',
#  'models/QVEQHHRRT_45748.pdb',
#  'models/NKFMAILQH_45658.pdb',
#  'models/VTLDGQQFY_45778.pdb',
#  'models/KAIDFLLQR_45717.pdb',
#  'models/KIEDLINQL_21.pdb',
#  'models/FVDTMSIYI_174.pdb',
#  'models/QLFNHTMFI_152.pdb',
#  'models/LFSYGTLII_45839.pdb',
#  'models/LSLLQLPRD_45839.pdb',
#  'models/LFEVDNLTY_1.pdb',
#  'models/LLSQYVDDA_45903.pdb',
#  'models/YTLNNGVAM_36.pdb',
#  'models/MVIFRLMRT_1.pdb',
#  'models/DTGEESASS_45840.pdb',
#  'models/ILSLPRIAL_45689.pdb',
#  'models/MHMVAGHDA_45778.pdb',
#  'models/QIGDIIIAV_45811.pdb',
#  'models/MHNQDGLIC_45690.pdb',
#  'models/IVIEAIHTV_400.pdb',
#  'models/VINRLGADL_0.4.pdb',
#  'models/TIHHASAPL_45690.pdb',
#  'models/GIKCIKKGV_1.pdb',
#  'models/QLKSVGLNL_1.pdb',
#  'models/SLAKHGEYA_45870.pdb',
#  'models/LMRTNFLIK_1.pdb',
#  'models/TSSDPGTNT_45839.pdb',
#  'models/RLEELLPAV_45841.pdb',
#  'models/RLNMFTPYI_1158.pdb',
#  'models/RMMGKTNPL_1098.pdb',
#  'models/AMISLAKKI_12.pdb',
#  'models/VSSGKNIKR_45811.pdb',
#  'models/CMIRWLGGI_45780.pdb',
#  'models/SFFLWVIIL_45779.pdb',
#  'models/TVAPPAPVY_45748.pdb',
#  'models/FLWVIILFQ_45809.pdb',
#  'models/IILKALYML_396.pdb',
#  'models/SYRNFSFSL_228.pdb',
#  'models/IISALVGIV_71.pdb',
#  'models/GMGPSLIGL_396.pdb',
#  'models/MKDEPVVFS_45810.pdb',
#  'models/QGLIQYPTA_45779.pdb',
#  'models/ILTLANWCL_480.pdb',
#  'models/TTGKLIWKV_1.pdb',
#  'models/FMYEGDTPL_2016.pdb',
#  'models/RFEVKKRDG_45839.pdb',
#  'models/SQDTTIPDV_45810.pdb',
#  'models/FGLYKSINV_45749.pdb',
#  'models/SQMTSTFIM_45870.pdb',
#  'models/MMLSPLVAL_216.pdb',
#  'models/YHMMKDEPV_1.pdb',
#  'models/FMYSDFHFI_1008.pdb',
#  'models/YLPDPTVGV_1350.pdb',
#  'models/IRWLGGILP_45779.pdb',
#  'models/FLPKLVVGE_45778.pdb',
#  'models/SLYPNVCIF_45658.pdb',
#  'models/QLNETIYTS_45659.pdb',
#  'models/GILKSILKV_54.pdb',
#  'models/FTPQFLLQL_45778.pdb',
#  'models/ILSAVVGIL_106.pdb',
#  'models/IQNVPGPHR_45810.pdb',
#  'models/LESGAVKYL_45809.pdb',
#  'models/KQWIVAGAI_36.pdb',
#  'models/DDQEKKILM_45839.pdb',
#  'models/WMIHTLEAL_294.pdb',
#  'models/TVMINNVKL_47.pdb',
#  'models/LVCGLRQLA_45689.pdb',
#  'models/RLDPRLAPV_1554.pdb',
#  'models/LLIHQGMHM_45901.pdb',
#  'models/FVRLDRPHT_45871.pdb',
#  'models/FVVDTTPPL_384.pdb',
#  'models/IMDQVPFSV_1470.pdb',
#  'models/NYLFGGFST_45778.pdb',
#  'models/KIMASENSS_1.pdb',
#  'models/KLLLWFNYL_5.pdb',
#  'models/ALSPVIPHI_2862.pdb',
#  'models/LIGFALFGV_174.pdb',
#  'models/FLTQDLPLL_1770.pdb',
#  'models/VLGSWPVDL_24.pdb',
#  'models/FLLRRWGGT_45839.pdb',
#  'models/YTIEGIAFM_36.pdb',
#  'models/KLMPICMDV_780.pdb',
#  'models/RFKRTSFFL_1.pdb',
#  'models/WLDSVIQYL_180.pdb',
#  'models/ATEDPSSGY_45659.pdb',
#  'models/RLMRTNFLI_45841.pdb',
#  'models/VLIRRCHYL_510.pdb',
#  'models/GKLGLITNT_45778.pdb',
#  'models/LIHQGMHMV_45871.pdb',
#  'models/GLMWLSYFV_116.pdb',
#  'models/AMILAAYHP_912.pdb',
#  'models/FAPGFFPYL_78.pdb',
#  'models/NLVPMVATV_456.pdb',
#  'models/TEQAFYTRV_45659.pdb',
#  'models/QYPTAWQSV_5.pdb',
#  'models/AVLYYHMMK_45658.pdb',
#  'models/KFLDWMIFI_36.pdb',
#  'models/EYKTLCDMI_45750.pdb',
#  'models/TVYDINNEV_120.pdb',
#  'models/LARTAKVKN_1.pdb',
#  'models/LPWTKISET_45779.pdb',
#  'models/LFPQLSAIA_45839.pdb',
#  'models/VIILFQRTF_1.pdb',
#  'models/VQRQIQVHA_45778.pdb',
#  'models/GTSNRTPTV_45810.pdb',
#  'models/TLRVLQDQL_45758.pdb',
#  'models/EWAFWENKK_45839.pdb',
#  'models/YLFEVDNLT_45749.pdb',
#  'models/PMLYQLLEA_45689.pdb',
#  'models/VLVKSPNHV_42.pdb',
#  'models/YLHPKDKYL_132.pdb',
#  'models/SISKSNAKC_45779.pdb',
#  'models/MLMAASRAL_516.pdb',
#  'models/KSSFFVWVI_45748.pdb',
#  'models/LVINRLGAD_45778.pdb',
#  'models/YGTLIIDEV_1.pdb',
#  'models/AKLTEAITA_45779.pdb',
#  'models/FLDPATTTS_45750.pdb',
#  'models/RVGRVNPGT_1.pdb',
#  'models/SMFLMTATL_45904.pdb',
#  'models/YVIRAQLHV_192.pdb',
#  'models/LLAVSSILL_228.pdb',
#  'models/MHNQNALVC_45748.pdb',
#  'models/GVIHNSTLQ_45748.pdb',
#  'models/YHLGGIEGL_24.pdb',
#  'models/TAQEQHNAA_45839.pdb',
#  'models/SLIGLAMGD_1032.pdb',
#  'models/KLFSDISAI_786.pdb',
#  'models/MMVIFRLMR_45840.pdb',
#  'models/YLKKWLNSF_6.pdb',
#  'models/VMDSIDVKI_306.pdb',
#  'models/FLQFKTWWI_733.2.pdb',
#  'models/FLWGFFPYL_1962.pdb',
#  'models/QVSDVDKLV_45809.pdb',
#  'models/SSGYYSTTI_45748.pdb',
#  'models/LMHNQDGLI_45748.pdb',
#  'models/ILVGDNSFV_192.pdb',
#  'models/AMKGDLQSS_102.pdb',
#  'models/ILLSCIHTT_1008.pdb',
#  'models/FLPQILAEC_690.pdb',
#  'models/GLLDWGMQQ_12.pdb',
#  'models/GLDDQEKKI_45717.pdb',
#  'models/RLYEWQHVS_288.pdb',
#  'models/NTSKSTDFL_1.pdb',
#  'models/ATGKCNPNL_45718.pdb',
#  'models/SIFERIREA_120.pdb',
#  'models/AAIGLAWIP_45778.pdb',
#  'models/QIDKNKLYL_3.pdb',
#  'models/WMIKETACL_246.pdb',
#  'models/VTLNASQYA_1.pdb',
#  'models/LLWFNYLFG_45902.pdb',
#  'models/YLMPYSVYI_2178.pdb',
#  'models/KSINVEYRF_1.pdb',
#  'models/WAFWETKKN_1.pdb',
#  'models/ASDTPSATT_45748.pdb',
#  'models/HLVEALYLV_1290.pdb',
#  'models/VTLRKERLA_45809.pdb',
#  'models/GIYGAVIPL_84.pdb',
#  'models/EYLFEVDNL_45839.pdb',
#  'models/FMKVKFEAL_6.pdb',
#  'models/RLASTVIYR_45689.pdb',
#  'models/LLWNGPMAV_2292.pdb',
#  'models/GRLIWTLDA_45870.pdb',
#  'models/GLICGLRQL_45781.pdb',
#  'models/ALSNGIPPV_2538.pdb',
#  'models/FSILNRKAI_45780.pdb',
#  'models/DMWEHAFYL_360.pdb',
#  'models/SGQSPARTS_45839.pdb',
#  'models/LMLCLHHAY_45717.pdb',
#  'models/LFLPKLVVG_45689.pdb',
#  'models/AMPGVLSYV_576.pdb',
#  'models/GLSIVMPVG_126.pdb',
#  'models/KLFIRQEEV_114.pdb',
#  'models/AIALGVATA_45749.pdb',
#  'models/SVVCFFFLV_2400.pdb',
#  'models/SMVNGVVRL_114.pdb',
#  'models/SLTDRELLL_228.pdb',
#  'models/GVPPKVVNY_45871.pdb',
#  'models/DMDYHKILT_45748.pdb',
#  'models/WVIILFQKA_45659.pdb',
#  'models/HLHQQLSNT_45839.pdb',
#  'models/YLYFCSSDV_384.pdb',
#  'models/VIRANNNRL_45748.pdb',
#  'models/AFFLYDRLA_45748.pdb',
#  'models/HMMVIFRLM_45778.pdb',
#  'models/MRTNFLIKF_1.pdb',
#  'models/SLPKTSGHY_45809.pdb',
#  'models/YVIRDLAAM_30.pdb',
#  'models/ELFDSLFPV_4800.pdb',
#  'models/YLDYDTIYV_828.pdb',
#  'models/FLDPASIAA_594.pdb',
#  'models/PWLTEKEAM_45873.pdb',
#  'models/ELDDYMFFV_138.pdb',
#  'models/IRSEELSFT_45778.pdb',
#  'models/AALSSLAKH_45901.pdb',
#  'models/RPVVLTGGT_45717.pdb',
#  'models/ILIDTSAWV_732.pdb',
#  'models/GIYHDICEI_60.pdb',
#  'models/LPRIALVRL_45749.pdb',
#  'models/GLDPTGVAV_108.pdb',
#  'models/IDQIIHDFV_45901.pdb',
#  'models/FLAVGGVLL_156.pdb',
#  'models/FLGQADFSL_516.pdb',
#  'models/FRSGVPPKV_45778.pdb',
#  'models/LSLPRIALV_45839.pdb',
#  'models/TLVGVVVST_3.pdb',
#  'models/RWGFRSGVP_45780.pdb',
#  'models/AMMARDTAE_864.pdb',
#  'models/LILAKPKET_45778.pdb',
#  'models/RTLAAMPEE_45839.pdb',
#  'models/PVILSLPRI_1.pdb',
#  'models/FMFNDLLKL_456.pdb',
#  'models/RTFSIPLGV_45719.pdb',
#  'models/KNISGQSPA_45839.pdb',
#  'models/YIDISDVKV_49.pdb',
#  'models/SLEEEYPPW_45779.pdb',
#  'models/YNIDRLNAL_24.pdb',
#  'models/KVDDTFYYV_594.pdb',
#  'models/AMDTISVFL_660.pdb',
#  'models/VLDEPSIGL_228.pdb',
#  'models/TLIIDEVHE_45870.pdb',
#  'models/LQSPPIREA_45658.pdb',
#  'models/LTLGEFLKL_180.pdb',
#  'models/AMNEENRFV_45779.pdb',
#  'models/RAADEPPLV_45840.pdb',
#  'models/YQGDYKLFL_45902.pdb',
#  'models/SLFLPKLVV_45750.pdb',
#  'models/LITGGRRTR_45842.pdb',
#  'models/GLAWIPYFG_45778.pdb',
#  'models/RLAKLTEAI_45689.pdb',
#  'models/TLFVIVPVL_240.pdb',
#  'models/LITCKAFGL_45809.pdb',
#  'models/FSTLDKITD_45873.pdb',
#  'models/MVTLRKERL_45840.pdb',
#  'models/DVDKLVCRD_45903.pdb',
#  'models/WLIGFDFDV_1413.pdb',
#  'models/HHRRTDNDS_45809.pdb',
#  'models/GLNLEGNGV_45870.pdb',
#  'models/NLHYWTTQD_45751.pdb',
#  'models/LLGPVIGML_114.pdb',
#  'models/LPQTRWQAV_6.pdb',
#  'models/ALNELLQHV_1260.pdb',
#  'models/LTAGLSVQQ_45809.pdb',
#  'models/GMLRFANPL_45870.pdb',
#  'models/YVHKAQGTG_45719.pdb',
#  'models/QDGLICGLR_45812.pdb',
#  'models/EMQLKIDKL_49.pdb',
#  'models/KAIDFLLRR_45809.pdb',
#  'models/RTIHHASAP_45778.pdb',
#  'models/KIWMAPSLT_45873.pdb',
#  'models/ATNLEYKTL_45870.pdb',
#  'models/KLGLITNTI_45903.pdb',
#  'models/ALLKHRFEI_510.pdb',
#  'models/AVGSYVYSV_744.pdb',
#  'models/FLLQRWGGT_45840.pdb',
#  'models/GLIQYPTAW_45748.pdb',
#  'models/GILGSLGLR_45840.pdb',
#  'models/RMIAISAKV_588.pdb',
#  'models/QIIHDFVDK_2.pdb',
#  'models/FQMGGIGPM_12.pdb',
#  'models/IPLGVIHNS_45717.pdb',
#  'models/YTWNGTQWV_354.pdb',
#  'models/FLKPEETFV_462.pdb',
#  'models/KILMNFHQK_45901.pdb',
#  'models/SLHSLSVET_45901.pdb',
#  'models/SLADQLIHL_1044.pdb',
#  'models/TETKITFAL_45690.pdb',
#  'models/LLMLCLHHA_45750.pdb',
#  'models/LAKLTEAIT_45839.pdb',
#  'models/VIHNSTLQV_45902.pdb',
#  'models/FEWYYQSGL_48.pdb',
#  'models/KVTAASPML_45748.pdb',
#  'models/TNAMVTLRK_45778.pdb',
#  'models/NQNALVCGL_45748.pdb',
#  'models/FLNEDHWAS_60.pdb',
#  'models/HLSTAFARV_234.pdb',
#  'models/YLSSWTPVV_2004.pdb',
#  'models/LYDRLASTV_1.pdb',
#  'models/STHKLSLTK_45778.pdb',
#  'models/YNIDKIKDV_45689.pdb',
#  'models/PTLTTPENI_45809.pdb',
#  'models/MFLMTATLE_45809.pdb',
#  'models/KILTAGLSV_45903.pdb',
#  'models/FLDGNELTL_1212.pdb',
#  'models/DGIRGFPRC_45901.pdb',
#  'models/LMHNQNALV_45750.pdb',
#  'models/MLTPINEEA_45870.pdb',
#  'models/VLNETTNWL_66.pdb',
#  'models/FFLYDRLAS_45778.pdb',
#  'models/FIFLKKNEL_9.pdb',
#  'models/NGLITSTVT_45749.pdb',
#  'models/FLVINRLGA_45839.pdb',
#  'models/SMVKLPIFL_132.pdb',
#  'models/FLHGGDFGV_1584.pdb',
#  'models/QVSIIQEKL_45814.pdb',
#  'models/MNAPDDLVL_45809.pdb',
#  'models/ILFDRLPIA_1506.pdb',
#  'models/ARLLNLSGV_45748.pdb',
#  'models/GMHMVAGHD_2.pdb',
#  'models/GTTFAEGVV_1.pdb',
#  'models/RLTGREGAV_6.pdb',
#  'models/KRTSFFLWV_45780.pdb',
#  'models/KLLEPVLLL_1062.pdb',
#  'models/FVDVIIIKV_214.pdb',
#  'models/SVMATEEPT_1.pdb',
#  'models/GNLSPETLV_45748.pdb',
#  'models/ILYAHLHKL1848.pdb',
#  'models/SQYANCSSI_45839.pdb',
#  'models/MNEENRFVT_45811.pdb',
#  'models/KLLPDTAAV_1602.pdb',
#  'models/FRFEVKKRD_45870.pdb',
#  'models/ALFPIIWAL_1104.pdb',
#  'models/VCIDILRSL_45749.pdb',
#  'models/FNYLFGGFS_45779.pdb',
#  'models/FTIGNMFSL_120.pdb',
#  'models/LDISEATQV_45809.pdb',
#  'models/KINQIIHDF_1.pdb',
#  'models/QLLEAVYGN_45839.pdb',
#  'models/LLSSNLSWL_60.pdb',
#  'models/MIRWLGGIL_45902.pdb',
#  'models/RIPNSLHSL_45809.pdb',
#  'models/LIIPFIHLI_600.pdb',
#  'models/VATDVPSAT_45809.pdb',
#  'models/WFNYLFGGF_45840.pdb',
#  'models/EVNSFKAAL_1.pdb',
#  'models/SADSFLLML_45778.pdb',
#  'models/AASPMLYQL_45809.pdb',
#  'models/IDILRSLET_45748.pdb',
#  'models/KLDISEATQ_1.pdb',
#  'models/VHSQGREAA_1.pdb',
#  'models/SLFTEQAFY_1.pdb',
#  'models/GTLEFTPID_45870.pdb',
#  'models/AVSSGKNIK_45781.pdb',
#  'models/MSDIFHALV_24.pdb',
#  'models/IIQAFEAGV_45748.pdb',
#  'models/VLFDDLCEA_11985.pdb',
#  'models/FSMPLGVVT_45810.pdb',
#  'models/RLEEEINNQ_45870.pdb',
#  'models/CLHHAYQGD_45901.pdb',
#  'models/FKIDNNTFV_1.pdb',
#  'models/LPAVSSGKN_45901.pdb',
#  'models/PRCRYVHKV_1.pdb',
#  'models/AMPEEETTE_45901.pdb',
#  'models/HKNKFMAIL_45839.pdb',
#  'models/FLKIKVTAA_45839.pdb',
#  'models/IFINKLNGA_1.pdb',
#  'models/ELDHLGLDD_45809.pdb',
#  'models/KLWASFFQG_24.pdb',
#  'models/SLKDVLVSV_570.pdb',
#  'models/KLIDCYTFL_2436.6.pdb',
#  'models/PLKVKDIPF_6.pdb',
#  'models/QGDNDNWWT_45779.pdb',
#  'models/VIYRGTTFA_45779.pdb',
#  'models/SAWQGDTGI_54.pdb',
#  'models/MDSRPQKIW_45749.pdb',
#  'models/YMDGTMSQV_4932.pdb',
#  'models/KLTDSLSSQ_45870.pdb',
#  'models/ERLAKLTEA_45718.pdb',
#  'models/LQVSDVDKL_1.pdb',
#  'models/LYLVDYGLV_45809.pdb',
#  'models/LMWDNVGLV_846.pdb',
#  'models/VMLIGIEIL_45840.pdb',
#  'models/YLSGANLNL_762.pdb',
#  'models/LLYAHINAL_936.pdb',
#  'models/SMYQLMITI_480.pdb',
#  'models/ITAALAWSL_30.pdb',
#  'models/HSLSVETIT_45689.pdb',
#  'models/IMLEGETKL_45778.pdb',
#  'models/AMCRTPFSL_234.pdb',
#  'models/AFIHIPGDT_45810.pdb',
#  'models/RNLNVTTQS_45809.pdb',
#  'models/PGPDNSTHN_45749.pdb',
#  'models/WMYNIQPYL_486.pdb',
#  'models/GAFFLYDRL_45659.pdb']

# %%
df_pepdist = pd.DataFrame()

for model in models:

    matches = re.search('models/(\D+)_(.+).pdb',model)
    if matches:
        pep_seq = matches.groups()[0]
        # Extract numeric part of half_life and convert to float
        half_life = float(re.sub(r'[^\d.]', '', matches.groups()[1]))
    else:
        continue

    structure = parsePDB(model)
    peptide   = structure.select('chain A and backbone' )
    hla       = structure.select('chain B and backbone')

    peptide_coords = peptide.getCoords()
    hla_coords     = hla.getCoords()

    dist_matrix = buildDistMatrix(peptide_coords, hla_coords)

    dist_array = dist_matrix.flatten()

    # Concatenate pep_seq, half_life and dist_array to a single row
    row = pd.Series([pep_seq, half_life] + dist_array.tolist())
    df_pepdist = pd.concat([df_pepdist, row.to_frame().T], ignore_index=True)
# Out:
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1554 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1557 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1578 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1554 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1559 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1579 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1557 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1556 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1557 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1553 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1556 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1557 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1559 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1579 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1584 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1579 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1556 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1556 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1577 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1580 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1557 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1553 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1581 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1557 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1582 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1581 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1577 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1559 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1581 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1584 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1579 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1559 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1559 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.03s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1555 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1581 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1587 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1582 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1559 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1582 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1558 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1580 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1577 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1582 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1554 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1559 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1556 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1581 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1557 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1555 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1577 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1550 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1577 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1578 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1559 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1578 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1558 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1558 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1553 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1558 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1556 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1558 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1577 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1577 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1577 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1556 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1579 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1558 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1559 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1557 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1559 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1578 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1581 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1558 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1559 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1558 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1577 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1558 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1580 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1560 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1582 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1571 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1555 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1579 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1569 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.04s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1558 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1575 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1556 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1572 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1556 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1556 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1573 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1576 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1563 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1568 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1570 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1562 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1566 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1565 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1564 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1567 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1561 atoms and 1 coordinate set(s) were parsed in 0.02s.
# @> 1582 atoms and 1 coordinate set(s) were parsed in 0.01s.
# @> 1574 atoms and 1 coordinate set(s) were parsed in 0.01s.

# %%
df_pepdist.rename({0: 'peptide_seq', 1: 'half_life'}, axis=1, inplace=True)

# %%
# Total number of distances per row
num_dists = len(dist_array)

# Generate column names dynamically
dist_columns = [f'dist_{i+1}' for i in range(num_dists)]

# Create full column list
columns = ['peptide_seq', 'half_life'] + dist_columns

# Apply column names before saving
df_pepdist.columns = columns

# %%
df_pepdist.to_csv('df_pepdist_2025_04_24.csv', index=False)

# %%
df_pepdist = pd.read_csv('df_pepdist_2025_04_24.csv')

# %%
dist_min = dist_array.min()
dist_max = dist_array.max()
dist_avg = dist_array.mean()
row = pd.Series([pep_seq, half_life, dist_min, dist_max, dist_avg])

# %%
df = pd.read_csv("df_pepdist_2025_04_24.csv")
df.head()           # First 5 rows
df.sample(5)        # Random 5 rows
df.describe()       # Statistics
# Out:
#           half_life      dist_1      dist_2      dist_3      dist_4  \
# count    459.000000  459.000000  459.000000  459.000000  459.000000
# mean   24806.734641   20.117925   21.489726   21.881823   21.243883
# std    22606.687952    0.111698    0.106600    0.117302    0.141322
# min        0.400000   19.839033   21.243765   21.504365   20.812181
# 25%      180.000000   20.041221   21.421894   21.805762   21.152268
# 50%    45689.000000   20.110592   21.479840   21.893502   21.255439
# 75%    45809.000000   20.184074   21.533471   21.957563   21.346523
# max    47348.000000   20.673696   22.104466   22.446717   21.710644
#
#            dist_5      dist_6      dist_7      dist_8      dist_9  ...  \
# count  459.000000  459.000000  459.000000  459.000000  459.000000  ...
# mean    23.026989   23.620303   24.219363   24.549384   24.477132  ...
# std      0.129627    0.179842    0.139275    0.154230    0.144415  ...
# min     22.536616   22.991434   23.735603   24.096300   24.047427  ...
# 25%     22.937362   23.495286   24.129399   24.456007   24.386493  ...
# 50%     23.044255   23.621921   24.222020   24.556532   24.464241  ...
# 75%     23.118331   23.777185   24.307662   24.635274   24.552600  ...
# max     23.517124   24.194957   24.995402   25.735893   25.054701  ...
#
#        dist_26199  dist_26200  dist_26201  dist_26202  dist_26203  dist_26204  \
# count  459.000000  459.000000  459.000000  459.000000  459.000000  459.000000
# mean    40.137110   39.233742   41.297992   41.670428   41.903333   42.305772
# std      0.364492    0.432770    0.296422    0.303534    0.353992    0.369008
# min     39.130793   38.305943   40.411397   41.000687   41.186274   41.507801
# 25%     39.937399   39.024347   41.123116   41.496351   41.739740   42.139157
# 50%     40.121185   39.209464   41.288204   41.637222   41.867796   42.275766
# 75%     40.307404   39.373404   41.450315   41.823004   42.021484   42.436220
# max     43.681107   43.981512   44.303825   45.362560   46.657673   47.146843
#
#        dist_26205  dist_26206  dist_26207  dist_26208
# count  459.000000  459.000000  459.000000  459.000000
# mean    41.670583   41.974698   43.474557   43.959634
# std      0.377758    0.461254    0.409840    0.377295
# min     41.121433   41.425205   42.861095   43.163498
# 25%     41.506247   41.808109   43.310716   43.795466
# 50%     41.644401   41.923626   43.429633   43.917259
# 75%     41.766824   42.042974   43.549847   44.043340
# max     46.745992   48.156102   49.050246   48.910564
#
# [8 rows x 26209 columns]

# %%
df['dist_min'] = df.filter(like='dist_').min(axis=1)
df['dist_max'] = df.filter(like='dist_').max(axis=1)
df['dist_mean'] = df.filter(like='dist_').mean(axis=1)
df['dist_std'] = df.filter(like='dist_').std(axis=1)

# %%
import pandas as pd
import numpy as np
import torch 
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 1. Load and prepare the data
df = pd.read_csv('df_pepdist_2025_04_24.csv')

# 2. Categorize half-life values 
def categorize_half_life(half_life):
    if half_life < 100:
        return 0  # Unstable
    elif half_life < 1000:
        return 1  # Moderately stable
    else:
        return 2  # Stable

df['stability_class'] = df['half_life'].apply(categorize_half_life)

# %%
# 3. Separate features and target
# Get peptide sequences
peptide_sequences = df['peptide_seq'].values

# Get distance measurements
distance_columns = [col for col in df.columns if col.startswith('dist_')]
distance_features = df[distance_columns].values

# Get target variable
y = df['stability_class'].values

# %%
# 4. Encode peptide sequences
def encode_peptide(peptide_seq):
    # One-hot encoding for amino acids
    amino_acids = "ACDEFGHIKLMNPQRSTVWY"
    encoding = np.zeros((len(peptide_seq), len(amino_acids)))
    
    for i, aa in enumerate(peptide_seq):
        if aa in amino_acids:
            encoding[i, amino_acids.index(aa)] = 1
    
    return encoding.flatten()  # Returns a 1D array

# Apply encoding to all peptides
peptide_features = np.array([encode_peptide(seq) for seq in peptide_sequences])

# %%
# 5. Normalize distance features
scaler = StandardScaler()
normalized_distances = scaler.fit_transform(distance_features)

# 6. Create PyTorch Dataset
class PMHCDataset(Dataset):
    def __init__(self, peptide_features, distance_features, labels):
        self.peptide_features = torch.FloatTensor(peptide_features)
        self.distance_features = torch.FloatTensor(distance_features)
        self.labels = torch.LongTensor(labels)
    def __len__(self):
        return len(self.labels)
        
    def __getitem__(self, idx):
        return {
            'peptide': self.peptide_features[idx], 
            'distances': self.distance_features[idx],
            'label': self.labels[idx]
        }

# %%
# 7. Split data and create dataloaders
X_peptide_train, X_peptide_test, X_dist_train, X_dist_test, y_train, y_test = train_test_split(
    peptide_features, normalized_distances, y, test_size=0.2, stratify=y, random_state=42)

# Create datasets
train_dataset = PMHCDataset(X_peptide_train, X_dist_train, y_train)
test_dataset = PMHCDataset(X_peptide_test, X_dist_test, y_test)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16)

# %%
# 8. Define your PyTorch model
import torch.nn as nn
import torch.optim as optim

class PMHCStabilityModel(nn.Module):
    def __init__(self, peptide_dim, distance_dim, hidden_dim=64, num_classes=3):
        super(PMHCStabilityModel, self).__init__()
        
        # Peptide processing branch
        self.peptide_network = nn.Sequential(
            nn.Linear(peptide_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.3)
        )
        # Distance processing branch
        self.distance_network = nn.Sequential(
            nn.Linear(distance_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.3)
        )
        
        # Combined processing
        self.combined_network = nn.Sequential(
            nn.Linear(hidden_dim*2, hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_dim, num_classes)
        )
    def forward(self, peptide, distances):
        peptide_features = self.peptide_network(peptide)
        distance_features = self.distance_network(distances)
        
        combined = torch.cat((peptide_features, distance_features), dim=1)
        output = self.combined_network(combined)
        
        return output

# %%
# 9. Initialize model
model = PMHCStabilityModel(
    peptide_dim=peptide_features.shape[1],  # Size of one-hot encoded peptide
    distance_dim=normalized_distances.shape[1]  # Number of distance features
)

# %%
# 10. Define training function
def train_model(model, train_loader, test_loader, epochs=100):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10)
    
    train_losses = []
    test_accuracies = []
    
    for epoch in range(epochs):
        # Training phase
        model.train()
        running_loss = 0.0
        for batch in train_loader:
            optimizer.zero_grad()
            outputs = model(batch['peptide'], batch['distances'])
            loss = criterion(outputs, batch['label'])
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        epoch_loss = running_loss / len(train_loader)
        train_losses.append(epoch_loss)
        scheduler.step(epoch_loss)
        
        # Evaluation phase
        if epoch % 5 == 0 or epoch == epochs-1:
            model.eval()
            correct = 0
            total = 0
            with torch.no_grad():
                for batch in test_loader:
                    outputs = model(batch['peptide'], batch['distances'])
                    _, predicted = torch.max(outputs, 1)
                    total += batch['label'].size(0)
                    correct += (predicted == batch['label']).sum().item()
            
            accuracy = 100 * correct / total
            test_accuracies.append(accuracy)
            
            print(f'Epoch {epoch+1}/{epochs}: '
                  f'Loss: {epoch_loss:.4f}, '
                  f'Test Accuracy: {accuracy:.2f}%')
    
    return model, train_losses, test_accuracies

# %%
# 11. Train the model
trained_model, losses, accuracies = train_model(model, train_loader, test_loader, epochs=100)

# 12. Final evaluation
from sklearn.metrics import classification_report, confusion_matrix

def evaluate_model(model, test_loader):
    model.eval()
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for batch in test_loader:
            outputs = model(batch['peptide'], batch['distances'])
            _, predicted = torch.max(outputs, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(batch['label'].cpu().numpy())
    
    print("\nClassification Report:")
    print(classification_report(all_labels, all_preds))
    
    print("\nConfusion Matrix:")
    print(confusion_matrix(all_labels, all_preds))
    return all_preds, all_labels

# Evaluate the trained model
predictions, true_labels = evaluate_model(trained_model, test_loader)
# Out:
# Epoch 1/100: Loss: 1.9664, Test Accuracy: 64.13%
# Epoch 6/100: Loss: 0.9061, Test Accuracy: 59.78%
# Epoch 11/100: Loss: 0.7589, Test Accuracy: 67.39%
# Epoch 16/100: Loss: 0.6377, Test Accuracy: 63.04%
# Epoch 21/100: Loss: 0.6342, Test Accuracy: 65.22%
# Epoch 26/100: Loss: 0.4989, Test Accuracy: 69.57%
# Epoch 31/100: Loss: 0.4389, Test Accuracy: 60.87%
# Epoch 36/100: Loss: 0.3691, Test Accuracy: 65.22%
# Epoch 41/100: Loss: 0.3799, Test Accuracy: 65.22%
# Epoch 46/100: Loss: 0.3467, Test Accuracy: 64.13%
# Epoch 51/100: Loss: 0.2009, Test Accuracy: 60.87%
# Epoch 56/100: Loss: 0.2167, Test Accuracy: 63.04%
# Epoch 61/100: Loss: 0.2920, Test Accuracy: 61.96%
# Epoch 66/100: Loss: 0.1953, Test Accuracy: 68.48%
# Epoch 71/100: Loss: 0.1468, Test Accuracy: 66.30%
# Epoch 76/100: Loss: 0.0903, Test Accuracy: 65.22%
# Epoch 81/100: Loss: 0.0856, Test Accuracy: 65.22%
# Epoch 86/100: Loss: 0.0971, Test Accuracy: 65.22%
# Epoch 91/100: Loss: 0.0513, Test Accuracy: 67.39%
# Epoch 96/100: Loss: 0.0371, Test Accuracy: 68.48%
# Epoch 100/100: Loss: 0.0487, Test Accuracy: 65.22%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.33      0.16      0.21        19
#            1       0.60      0.53      0.56        17
#            2       0.71      0.86      0.77        56
#
#     accuracy                           0.65        92
#    macro avg       0.55      0.51      0.52        92
# weighted avg       0.61      0.65      0.62        92
#
#
# Confusion Matrix:
# [[ 3  1 15]
#  [ 3  9  5]
#  [ 3  5 48]]

# %%
# Save a lighter CSV with the first 50 columns for testing Rainbow CSV
import pandas as pd  # Ensure pandas is imported
df = pd.read_csv('df_pepdist_2025_04_24.csv')  # Load the CSV into a DataFrame
reduced_df = df.iloc[:, :50]  # Select the first 50 columns
# Save the file to the current working directory
reduced_df.to_csv("df_pepdist_small_preview.csv", index=False)
